# %%
import sys
sys.path.append('../src')  # So Python can find your src/ folder

from data_processing import download_stock_data, split_data, scale_data, prepare_sequences
from model import build_lstm_model

# Step 1: Load data
data = download_stock_data()
print(data) 
# Step 2: Visualize
import matplotlib.pyplot as plt

ma_100_days = data.Close.rolling(100).mean()
ma_200_days = data.Close.rolling(200).mean()

ma_100_days = data.Close.rolling(100).mean()
plt.figure(figsize=(8,6))
plt.plot(ma_100_days, 'r', label='MA 100')
plt.plot(data.Close, 'g', label='Closing Price')
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
plt.plot(ma_100_days, 'r', label='MA 100')
plt.plot(ma_200_days, 'b', label='MA 200')
plt.plot(data.Close, 'g', label='Closing Price')
plt.legend()
plt.show()

# Step 3: Preprocess
data_train, data_test = split_data(data)
data_train_scaled, scaler = scale_data(data_train)
x, y = prepare_sequences(data_train_scaled)

# Step 4: Build and train model
model = build_lstm_model((x.shape[1], 1))
model.fit(x, y, epochs=50, batch_size=32, verbose=1)

# Summary
model.summary()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Date       Close        High         Low        Open    Volume
# Ticker                   GOOG        GOOG        GOOG        GOOG      GOOG
# 0      2015-01-02   26.045290   26.365888   26.010055   26.253728  28951268
# 1      2015-01-05   25.502359   26.021469   25.462162   25.968366  41196796
# 2      2015-01-06   24.911289   25.616753   24.866129   25.558439  57998800
# 3      2015-01-07   24.868612   25.173526   24.796651   25.161417  41301082
# 4      2015-01-08   24.947023   24.986726   24.367368   24.714268  67071641
# ...           ...         ...         ...         ...         ...       ...
# 2511   2024-12-24  197.345184  197.445061  194.975874  195.946768   6809800
# 2512   2024-12-26  196.875717  197.934509  195.647106  196.516126   7907900
# 2513   2024-12-27  193.819183  196.576052  191.753543  196.246426  14693000
# 2514   2024-12-30  192.470734  193.559490  190.143383  190.647813  12209500
# 2515   2024-12-31  190.223282  193.030082  189.364260  192.226005  14355200
#
# [2516 rows x 6 columns]
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 167ms/step - loss: 0.0859
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - loss: 0.0070
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 168ms/step - loss: 0.0059
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - loss: 0.0057
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 196ms/step - loss: 0.0074
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 175ms/step - loss: 0.0061
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 184ms/step - loss: 0.0054
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - loss: 0.0049
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 187ms/step - loss: 0.0046
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - loss: 0.0050
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - loss: 0.0045
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 183ms/step - loss: 0.0047
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - loss: 0.0045
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 159ms/step - loss: 0.0043
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - loss: 0.0042
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 155ms/step - loss: 0.0040
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 149ms/step - loss: 0.0038
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 161ms/step - loss: 0.0041
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 150ms/step - loss: 0.0048
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 154ms/step - loss: 0.0039
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 155ms/step - loss: 0.0036
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 163ms/step - loss: 0.0036
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - loss: 0.0036
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 154ms/step - loss: 0.0036
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 147ms/step - loss: 0.0038
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 145ms/step - loss: 0.0032
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 168ms/step - loss: 0.0029
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 167ms/step - loss: 0.0030
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 175ms/step - loss: 0.0026
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - loss: 0.0034
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 158ms/step - loss: 0.0032
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - loss: 0.0028
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 148ms/step - loss: 0.0032
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - loss: 0.0027
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 168ms/step - loss: 0.0027
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 155ms/step - loss: 0.0028
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - loss: 0.0029
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 147ms/step - loss: 0.0029
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 153ms/step - loss: 0.0031
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - loss: 0.0030
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - loss: 0.0025
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 155ms/step - loss: 0.0024
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 149ms/step - loss: 0.0025
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 153ms/step - loss: 0.0032
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 152ms/step - loss: 0.0027
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - loss: 0.0027
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 165ms/step - loss: 0.0028
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - loss: 0.0023
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 150ms/step - loss: 0.0022
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - loss: 0.0023
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 100, 50)             │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 100, 50)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 100, 60)             │          26,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 100, 60)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 100, 80)             │          45,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 100, 80)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 120)                 │          96,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 120)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             121 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 536,285 (2.05 MB)
#  Trainable params: 178,761 (698.29 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 357,524 (1.36 MB)
